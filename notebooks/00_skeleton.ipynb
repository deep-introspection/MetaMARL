# %% [markdown]
# # Brick 0 — Project skeleton
#
# First pedagogical notebook of the `bilevel-fishery` rebuild.
#
# Goal: verify that the base tooling works before tackling Brick 1 (ecological model).
#
# If this notebook runs end-to-end, the skeleton is healthy.

# %% [markdown]
# ## 1. The package imports and exposes a version

# %%
import bilevel_fishery

print(f"bilevel_fishery version: {bilevel_fishery.__version__}")

# %% [markdown]
# ## 2. Centralized logging works

# %%
import logging

from bilevel_fishery._logging import setup_logging

setup_logging("DEBUG")
logger = logging.getLogger("brick-0-demo")

logger.debug("Debug message — visible because we are in DEBUG")
logger.info("Info message — unified format: asctime | name | levelname | message")
logger.warning("Warning message — useful for atypical conditions")

# %% [markdown]
# ## 3. Next step
#
# **Brick 1** introduces a pure ecological model (predator-prey Lotka-Volterra fish/algae) with numpy and scipy.
#
# The following notebooks will show how each brick layers on top of the previous ones.
