# %% [markdown]
# # Brique 0 — Squelette du projet
#
# Premier notebook pédagogique de la reconstruction `bilevel-fishery`.
#
# Objectif : vérifier que l'outillage de base fonctionne avant d'attaquer la brique 1 (modèle écologique).
#
# Si ce notebook s'exécute de bout en bout, le squelette est sain.

# %% [markdown]
# ## 1. Le package s'importe et expose une version

# %%
import bilevel_fishery

print(f"bilevel_fishery version : {bilevel_fishery.__version__}")

# %% [markdown]
# ## 2. Le logging centralisé fonctionne

# %%
import logging

from bilevel_fishery._logging import setup_logging

setup_logging("DEBUG")
logger = logging.getLogger("brique-0-demo")

logger.debug("Message debug — visible parce qu'on est en DEBUG")
logger.info("Message info — format unifié : asctime | name | levelname | message")
logger.warning("Message warning — utile pour signaler des conditions atypiques")

# %% [markdown]
# ## 3. Prochaine étape
#
# **Brique 1** introduira un modèle écologique pur (Lotka-Volterra poissons/algues) avec numpy et scipy.
#
# Les notebooks suivants montreront comment chaque brique s'imbrique avec les précédentes.
